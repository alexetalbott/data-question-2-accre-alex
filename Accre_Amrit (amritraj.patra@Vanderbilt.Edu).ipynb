# %% [markdown]
# # Accor Data

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import time
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
accre = pd.read_csv('./data/july-2017-thru-june-2018.txt', sep="|", chunksize=5000).get_chunk() 
accre.head(10)
# Out:
#       JobID  JobIDRaw Cluster   Partition      Account        Group    GID  \
# 0  15806649  15806649   accre  production      h_vuiis      h_vuiis  36052
# 1  15806664  15806664   accre  production      h_vuiis      h_vuiis  36052
# 2  15806670  15806670   accre  production      h_vuiis      h_vuiis  36052
# 3  15806671  15806671   accre  production      h_vuiis      h_vuiis  36052
# 4  15811617  15811617   accre  production  cms_samtest  cms_samtest  59297
# 5  15811618  15811618   accre  production   cms_stage2   cms_stage1  59298
# 6  15811619  15811619   accre  production   cms_stage2          cms  31000
# 7  15811621  15811621   accre  production  cms_samtest  cms_samtest  59297
# 8  15811624  15811624   accre  production   cms_stage2   cms_stage1  59298
# 9  15811625  15811625   accre  production   cms_stage2          cms  31000
#
#          User       UID               Submit  \
# 0  masispider       NaN  2017-07-02T00:40:58
# 1  masispider       NaN  2017-07-02T00:40:58
# 2  masispider       NaN  2017-07-02T00:40:58
# 3  masispider       NaN  2017-07-02T00:40:58
# 4    uscms010       NaN  2017-07-01T05:00:00
# 5     autocms    9209.0  2017-07-01T05:00:01
# 6        tuos  126986.0  2017-07-01T05:00:02
# 7    uscms010       NaN  2017-07-01T05:00:22
# 8     autocms    9209.0  2017-07-01T05:01:01
# 9        tuos  126986.0  2017-07-01T05:01:02
#
#                          ...                              State NNodes NCPUS  \
# 0                        ...                          COMPLETED      1     2
# 1                        ...                          COMPLETED      1     2
# 2                        ...                          COMPLETED      1     2
# 3                        ...                          COMPLETED      1     2
# 4                        ...                          COMPLETED      1     1
# 5                        ...                          COMPLETED      1     1
# 6                        ...                          COMPLETED      1     1
# 7                        ...                          COMPLETED      1     1
# 8                        ...                          COMPLETED      1     1
# 9                        ...                          COMPLETED      1     1
#
#   ReqCPUS  ReqMem ReqGRES                 ReqTRES   Timelimit  NodeList  \
# 0       2    12Gn     NaN    cpu=2,mem=12G,node=1  9-04:00:00   vmp1085
# 1       2    12Gn     NaN    cpu=2,mem=12G,node=1  9-04:00:00   vmp1099
# 2       2    12Gn     NaN    cpu=2,mem=12G,node=1  9-04:00:00   vmp1126
# 3       2    12Gn     NaN    cpu=2,mem=12G,node=1  9-04:00:00    vmp230
# 4       1  4000Mn     NaN  cpu=1,mem=4000M,node=1  2-00:00:00   vmp1242
# 5       1     2Gc     NaN     cpu=1,mem=2G,node=1    12:00:00   vmp1063
# 6       1     2Gc     NaN     cpu=1,mem=2G,node=1    12:00:00   vmp1062
# 7       1  4000Mn     NaN  cpu=1,mem=4000M,node=1  2-00:00:00   vmp1242
# 8       1     2Gc     NaN     cpu=1,mem=2G,node=1    12:00:00    vmp670
# 9       1     2Gc     NaN     cpu=1,mem=2G,node=1    12:00:00   vmp1078
#
#                                              JobName
# 0  WOODWARD_TCP-x-228324-x-228324-x-301-x-Multi_A...
# 1  WOODWARD_TCP-x-115174-x-115174-x-301-x-Multi_A...
# 2  WOODWARD_TCP-x-215607-x-215607-x-301-x-Multi_A...
# 3  WOODWARD_TCP-x-116214-x-116214-x-1701-x-Multi_...
# 4                                    bl_aa7c22e04f21
# 5                                          skim_test
# 6                                          skim_test
# 7                                    bl_33ee450ebdc4
# 8                                          skim_test
# 9                                          skim_test
#
# [10 rows x 25 columns]

# %%
accre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 25 columns):
# JobID        5000 non-null object
# JobIDRaw     5000 non-null int64
# Cluster      5000 non-null object
# Partition    5000 non-null object
# Account      5000 non-null object
# Group        5000 non-null object
# GID          5000 non-null int64
# User         5000 non-null object
# UID          3821 non-null float64
# Submit       5000 non-null object
# Eligible     5000 non-null object
# Start        5000 non-null object
# End          5000 non-null object
# Elapsed      5000 non-null object
# ExitCode     5000 non-null object
# State        5000 non-null object
# NNodes       5000 non-null int64
# NCPUS        5000 non-null int64
# ReqCPUS      5000 non-null int64
# ReqMem       5000 non-null object
# ReqGRES      13 non-null object
# ReqTRES      5000 non-null object
# Timelimit    5000 non-null object
# NodeList     5000 non-null object
# JobName      5000 non-null object
# dtypes: float64(1), int64(5), object(19)
# memory usage: 976.6+ KB

# %%
accre.shape
# Out:
# (5000, 25)

# %%
accre.columns
# Out:
# Index(['JobID', 'JobIDRaw', 'Cluster', 'Partition', 'Account', 'Group', 'GID',
#        'User', 'UID', 'Submit', 'Eligible', 'Start', 'End', 'Elapsed',
#        'ExitCode', 'State', 'NNodes', 'NCPUS', 'ReqCPUS', 'ReqMem', 'ReqGRES',
#        'ReqTRES', 'Timelimit', 'NodeList', 'JobName'],
#       dtype='object')

# %%
# convert Submit and Start to datetime
accre['Submit'] = pd.to_datetime(accre['Submit'], format='%Y/%m/%d')
accre['Start'] = pd.to_datetime(accre['Start'], format='%Y/%m/%d')

# %%
# check head of Submit
accre.Submit.head()
# Out:
# 0   2017-07-02 00:40:58
# 1   2017-07-02 00:40:58
# 2   2017-07-02 00:40:58
# 3   2017-07-02 00:40:58
# 4   2017-07-01 05:00:00
# Name: Submit, dtype: datetime64[ns]

# %%
# check head of Start
accre.Start.head()
# Out:
# 0   2017-07-03 02:13:59
# 1   2017-07-03 02:20:08
# 2   2017-07-03 02:41:13
# 3   2017-07-03 02:51:53
# 4   2017-07-01 05:00:01
# Name: Start, dtype: datetime64[ns]

# %%
# create Queue_Time column = Start - Submit
accre['Queue_Time'] = accre['Start'] - accre['Submit']
accre.Queue_Time.head()
# Out:
# 0   1 days 01:33:01
# 1   1 days 01:39:10
# 2   1 days 02:00:15
# 3   1 days 02:10:55
# 4   0 days 00:00:01
# Name: Queue_Time, dtype: timedelta64[ns]

# %%
#remove unnecessary columns
cols = ['Partition', 'JobIDRaw', 'Cluster', 'UID', 'JobName']
accre_reduced = accre.drop(columns=cols)
accre_reduced.head()
# Out:
#       JobID      Account        Group    GID        User              Submit  \
# 0  15806649      h_vuiis      h_vuiis  36052  masispider 2017-07-02 00:40:58
# 1  15806664      h_vuiis      h_vuiis  36052  masispider 2017-07-02 00:40:58
# 2  15806670      h_vuiis      h_vuiis  36052  masispider 2017-07-02 00:40:58
# 3  15806671      h_vuiis      h_vuiis  36052  masispider 2017-07-02 00:40:58
# 4  15811617  cms_samtest  cms_samtest  59297    uscms010 2017-07-01 05:00:00
#
#               Eligible               Start                  End     Elapsed  \
# 0  2017-07-02T00:42:59 2017-07-03 02:13:59  2017-07-04T03:19:20  1-01:05:21
# 1  2017-07-02T00:42:59 2017-07-03 02:20:08  2017-07-04T02:11:55    23:51:47
# 2  2017-07-02T00:42:59 2017-07-03 02:41:13  2017-07-04T04:41:04  1-01:59:51
# 3  2017-07-02T00:42:59 2017-07-03 02:51:53  2017-07-04T10:54:13  1-08:02:20
# 4  2017-07-01T05:00:00 2017-07-01 05:00:01  2017-07-01T05:00:11    00:00:10
#
#         ...            State NNodes  NCPUS  ReqCPUS  ReqMem ReqGRES  \
# 0       ...        COMPLETED      1      2        2    12Gn     NaN
# 1       ...        COMPLETED      1      2        2    12Gn     NaN
# 2       ...        COMPLETED      1      2        2    12Gn     NaN
# 3       ...        COMPLETED      1      2        2    12Gn     NaN
# 4       ...        COMPLETED      1      1        1  4000Mn     NaN
#
#                   ReqTRES   Timelimit NodeList      Queue_Time
# 0    cpu=2,mem=12G,node=1  9-04:00:00  vmp1085 1 days 01:33:01
# 1    cpu=2,mem=12G,node=1  9-04:00:00  vmp1099 1 days 01:39:10
# 2    cpu=2,mem=12G,node=1  9-04:00:00  vmp1126 1 days 02:00:15
# 3    cpu=2,mem=12G,node=1  9-04:00:00   vmp230 1 days 02:10:55
# 4  cpu=1,mem=4000M,node=1  2-00:00:00  vmp1242 0 days 00:00:01
#
# [5 rows x 21 columns]

# %%
# pick columns: 'Elapsed', 'User', 'Group', 'Account'
accre_user_elapsed = accre.sort_values(by='Elapsed', ascending=False)[['JobID', 'Account', 'Group', 'GID', 'User', 'Submit', 'Elapsed']]
accre_user_elapsed.head(30)
# Out:
#              JobID      Account        Group    GID        User  \
# 16        15811634      h_vuiis      h_vuiis  36052    vuiiscci
# 26        15811644      h_vuiis      h_vuiis  36052    vuiiscci
# 18        15811636      h_vuiis      h_vuiis  36052    vuiiscci
# 22        15811640      h_vuiis      h_vuiis  36052    vuiiscci
# 24        15811642      h_vuiis      h_vuiis  36052    vuiiscci
# 28        15811646      h_vuiis      h_vuiis  36052    vuiiscci
# 27        15811645      h_vuiis      h_vuiis  36052    vuiiscci
# 21        15811639      h_vuiis      h_vuiis  36052    vuiiscci
# 1615      15813721  h_vangard_1  h_vangard_1  59353       guom1
# 15        15811633      h_vuiis      h_vuiis  36052    vuiiscci
# 17        15811635      h_vuiis      h_vuiis  36052    vuiiscci
# 30        15811648      h_vuiis      h_vuiis  36052    vuiiscci
# 23        15811641      h_vuiis      h_vuiis  36052    vuiiscci
# 19        15811637      h_vuiis      h_vuiis  36052    vuiiscci
# 29        15811647      h_vuiis      h_vuiis  36052    vuiiscci
# 10        15811628      h_vuiis      h_vuiis  36052    vuiiscci
# 13        15811631      h_vuiis      h_vuiis  36052    vuiiscci
# 32        15811650      h_vuiis      h_vuiis  36052    vuiiscci
# 20        15811638      h_vuiis      h_vuiis  36052    vuiiscci
# 25        15811643      h_vuiis      h_vuiis  36052    vuiiscci
# 12        15811630      h_vuiis      h_vuiis  36052    vuiiscci
# 14        15811632      h_vuiis      h_vuiis  36052    vuiiscci
# 11        15811629      h_vuiis      h_vuiis  36052    vuiiscci
# 4850  15817724_153      p_iglab      p_iglab  20440     nagarr1
# 1         15806664      h_vuiis      h_vuiis  36052  masispider
# 4953  15817724_256      p_iglab      p_iglab  20440     nagarr1
# 4784   15817724_87      p_iglab      p_iglab  20440     nagarr1
# 4769   15817724_72      p_iglab      p_iglab  20440     nagarr1
# 4740   15817724_43      p_iglab      p_iglab  20440     nagarr1
# 4721   15817724_24      p_iglab      p_iglab  20440     nagarr1
#
#                   Submit     Elapsed
# 16   2017-07-01 05:01:23  5-08:00:25
# 26   2017-07-01 05:01:25  5-08:00:21
# 18   2017-07-01 05:01:24  5-03:31:54
# 22   2017-07-01 05:01:24  4-23:00:02
# 24   2017-07-01 05:01:25  4-22:03:59
# 28   2017-07-01 05:01:26  4-21:59:47
# 27   2017-07-01 05:01:25  4-21:35:27
# 21   2017-07-01 05:01:24  4-21:28:44
# 1615 2017-07-01 10:34:24  4-19:52:41
# 15   2017-07-01 05:01:23  4-19:45:26
# 17   2017-07-01 05:01:24  4-19:34:20
# 30   2017-07-01 05:01:26  4-19:31:33
# 23   2017-07-01 05:01:25  4-16:30:23
# 19   2017-07-01 05:01:24  4-15:23:15
# 29   2017-07-01 05:01:26  4-13:05:09
# 10   2017-07-01 05:01:22  4-10:00:26
# 13   2017-07-01 05:01:23  4-09:44:46
# 32   2017-07-01 05:01:26  4-08:42:09
# 20   2017-07-01 05:01:24  4-08:30:10
# 25   2017-07-01 05:01:25  4-08:10:37
# 12   2017-07-01 05:01:23  4-03:19:43
# 14   2017-07-01 05:01:23  4-02:57:55
# 11   2017-07-01 05:01:22  3-18:07:18
# 4850 2017-07-01 20:24:38  3-00:00:04
# 1    2017-07-02 00:40:58    23:51:47
# 4953 2017-07-01 20:24:38    23:50:18
# 4784 2017-07-01 20:24:38    23:28:03
# 4769 2017-07-01 20:24:38    23:27:10
# 4740 2017-07-01 20:24:38    23:12:53
# 4721 2017-07-01 20:24:38    22:53:43

# %%
#randomization of dataset with reduced amount of data
#indices = np.random.randint(0, len(accre_user_elapsed), 500)
#random_elapsed = accre_user_elapsed.iloc[indices,:]
#random_elapsed.head(10)

# %%
#Checking stats of Elapsed
accre_user_elapsed.Elapsed.describe()
# Out:
# count         5000
# unique        1829
# top       00:00:10
# freq            89
# Name: Elapsed, dtype: object

# %%
#Extracting days and non-days time values from Elapsed
accre_user_elapsed['elapsed_days'] = accre_user_elapsed['Elapsed'].str.extract('(\d+)-', expand=True).fillna('0')
accre_user_elapsed['elapsed_hms'] = accre_user_elapsed['Elapsed'].str.extract('(\d+:\d+:\d+)', expand=True)
accre_user_elapsed.head(30)
# Out:
#              JobID      Account        Group    GID        User  \
# 16        15811634      h_vuiis      h_vuiis  36052    vuiiscci
# 26        15811644      h_vuiis      h_vuiis  36052    vuiiscci
# 18        15811636      h_vuiis      h_vuiis  36052    vuiiscci
# 22        15811640      h_vuiis      h_vuiis  36052    vuiiscci
# 24        15811642      h_vuiis      h_vuiis  36052    vuiiscci
# 28        15811646      h_vuiis      h_vuiis  36052    vuiiscci
# 27        15811645      h_vuiis      h_vuiis  36052    vuiiscci
# 21        15811639      h_vuiis      h_vuiis  36052    vuiiscci
# 1615      15813721  h_vangard_1  h_vangard_1  59353       guom1
# 15        15811633      h_vuiis      h_vuiis  36052    vuiiscci
# 17        15811635      h_vuiis      h_vuiis  36052    vuiiscci
# 30        15811648      h_vuiis      h_vuiis  36052    vuiiscci
# 23        15811641      h_vuiis      h_vuiis  36052    vuiiscci
# 19        15811637      h_vuiis      h_vuiis  36052    vuiiscci
# 29        15811647      h_vuiis      h_vuiis  36052    vuiiscci
# 10        15811628      h_vuiis      h_vuiis  36052    vuiiscci
# 13        15811631      h_vuiis      h_vuiis  36052    vuiiscci
# 32        15811650      h_vuiis      h_vuiis  36052    vuiiscci
# 20        15811638      h_vuiis      h_vuiis  36052    vuiiscci
# 25        15811643      h_vuiis      h_vuiis  36052    vuiiscci
# 12        15811630      h_vuiis      h_vuiis  36052    vuiiscci
# 14        15811632      h_vuiis      h_vuiis  36052    vuiiscci
# 11        15811629      h_vuiis      h_vuiis  36052    vuiiscci
# 4850  15817724_153      p_iglab      p_iglab  20440     nagarr1
# 1         15806664      h_vuiis      h_vuiis  36052  masispider
# 4953  15817724_256      p_iglab      p_iglab  20440     nagarr1
# 4784   15817724_87      p_iglab      p_iglab  20440     nagarr1
# 4769   15817724_72      p_iglab      p_iglab  20440     nagarr1
# 4740   15817724_43      p_iglab      p_iglab  20440     nagarr1
# 4721   15817724_24      p_iglab      p_iglab  20440     nagarr1
#
#                   Submit     Elapsed elapsed_days elapsed_hms
# 16   2017-07-01 05:01:23  5-08:00:25            5    08:00:25
# 26   2017-07-01 05:01:25  5-08:00:21            5    08:00:21
# 18   2017-07-01 05:01:24  5-03:31:54            5    03:31:54
# 22   2017-07-01 05:01:24  4-23:00:02            4    23:00:02
# 24   2017-07-01 05:01:25  4-22:03:59            4    22:03:59
# 28   2017-07-01 05:01:26  4-21:59:47            4    21:59:47
# 27   2017-07-01 05:01:25  4-21:35:27            4    21:35:27
# 21   2017-07-01 05:01:24  4-21:28:44            4    21:28:44
# 1615 2017-07-01 10:34:24  4-19:52:41            4    19:52:41
# 15   2017-07-01 05:01:23  4-19:45:26            4    19:45:26
# 17   2017-07-01 05:01:24  4-19:34:20            4    19:34:20
# 30   2017-07-01 05:01:26  4-19:31:33            4    19:31:33
# 23   2017-07-01 05:01:25  4-16:30:23            4    16:30:23
# 19   2017-07-01 05:01:24  4-15:23:15            4    15:23:15
# 29   2017-07-01 05:01:26  4-13:05:09            4    13:05:09
# 10   2017-07-01 05:01:22  4-10:00:26            4    10:00:26
# 13   2017-07-01 05:01:23  4-09:44:46            4    09:44:46
# 32   2017-07-01 05:01:26  4-08:42:09            4    08:42:09
# 20   2017-07-01 05:01:24  4-08:30:10            4    08:30:10
# 25   2017-07-01 05:01:25  4-08:10:37            4    08:10:37
# 12   2017-07-01 05:01:23  4-03:19:43            4    03:19:43
# 14   2017-07-01 05:01:23  4-02:57:55            4    02:57:55
# 11   2017-07-01 05:01:22  3-18:07:18            3    18:07:18
# 4850 2017-07-01 20:24:38  3-00:00:04            3    00:00:04
# 1    2017-07-02 00:40:58    23:51:47            0    23:51:47
# 4953 2017-07-01 20:24:38    23:50:18            0    23:50:18
# 4784 2017-07-01 20:24:38    23:28:03            0    23:28:03
# 4769 2017-07-01 20:24:38    23:27:10            0    23:27:10
# 4740 2017-07-01 20:24:38    23:12:53            0    23:12:53
# 4721 2017-07-01 20:24:38    22:53:43            0    22:53:43

# %%
# Converting elapsed_hms to date time format

def time_converter(x):
#    print(x.elapsed_hms)
    return timedelta(
         hours=(int(x['elapsed_days'][0]) * 24) + int(x['elapsed_hms'][0:2]),
         minutes=int(x['elapsed_hms'][3:5]),
         seconds=int(x['elapsed_hms'][6:])
     )

accre_user_elapsed['elapsed_time'] = accre_user_elapsed.apply(time_converter, axis=1)

accre_user_elapsed.head()
# Out:
#        JobID  Account    Group    GID      User              Submit  \
# 16  15811634  h_vuiis  h_vuiis  36052  vuiiscci 2017-07-01 05:01:23
# 26  15811644  h_vuiis  h_vuiis  36052  vuiiscci 2017-07-01 05:01:25
# 18  15811636  h_vuiis  h_vuiis  36052  vuiiscci 2017-07-01 05:01:24
# 22  15811640  h_vuiis  h_vuiis  36052  vuiiscci 2017-07-01 05:01:24
# 24  15811642  h_vuiis  h_vuiis  36052  vuiiscci 2017-07-01 05:01:25
#
#        Elapsed elapsed_days elapsed_hms    elapsed_time
# 16  5-08:00:25            5    08:00:25 5 days 08:00:25
# 26  5-08:00:21            5    08:00:21 5 days 08:00:21
# 18  5-03:31:54            5    03:31:54 5 days 03:31:54
# 22  4-23:00:02            4    23:00:02 4 days 23:00:02
# 24  4-22:03:59            4    22:03:59 4 days 22:03:59

# %%
accre_user_elapsed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5000 entries, 16 to 201
# Data columns (total 10 columns):
# JobID           5000 non-null object
# Account         5000 non-null object
# Group           5000 non-null object
# GID             5000 non-null int64
# User            5000 non-null object
# Submit          5000 non-null datetime64[ns]
# Elapsed         5000 non-null object
# elapsed_days    5000 non-null object
# elapsed_hms     5000 non-null object
# elapsed_time    5000 non-null timedelta64[ns]
# dtypes: datetime64[ns](1), int64(1), object(7), timedelta64[ns](1)
# memory usage: 429.7+ KB

# %%
accre_user_elapsed.elapsed_time.describe()
# Out:
# count                      5000
# mean     0 days 02:44:16.545400
# std      0 days 10:46:56.613227
# min             0 days 00:00:00
# 25%             0 days 00:01:42
# 50%             0 days 00:03:12
# 75%             0 days 01:04:02
# max             5 days 08:00:25
# Name: elapsed_time, dtype: object

# %%
accre_user_elapsed['User'].value_counts()
# Out:
# autocms       936
# tuos          935
# nagarr1       781
# uscms010      748
# mercalnd      600
# sotocs        503
# masispider    250
# cmsglidein    125
# vuiiscci       24
# guom1          17
# songhd         16
# cmslocal       16
# nabords1       15
# mothcw         13
# boydb1         12
# fletchs2        4
# malavejm        3
# yangkl          1
# sheedlmj        1
# Name: User, dtype: int64

# %%
#accre_user_elapsed.groupby('User')['elapsed_time'].value_counts()
accre_user_elapsed[accre_user_elapsed['elapsed_time'] < timedelta(minutes = 5)].groupby('User')['elapsed_time'].value_counts()
# Out:
# User      elapsed_time
# autocms   00:02:56        18
#           00:03:24        17
#           00:03:04        16
#           00:03:11        16
#           00:03:13        16
#           00:02:44        15
#           00:03:17        15
#           00:03:18        15
#           00:03:20        15
#           00:03:42        15
#           00:03:02        14
#           00:03:07        14
#           00:03:16        14
#           00:03:21        14
#           00:02:51        13
#           00:03:03        13
#           00:03:08        13
#           00:03:09        13
#           00:03:19        13
#           00:02:49        12
#           00:03:00        12
#           00:03:05        12
#           00:03:10        12
#           00:03:22        12
#           00:02:54        11
#           00:03:06        11
#           00:03:23        11
#           00:03:28        11
#           00:02:58        10
#           00:03:12        10
#                           ..
# uscms010  00:02:00         2
#           00:02:04         2
#           00:02:18         2
#           00:00:09         1
#           00:00:31         1
#           00:00:36         1
#           00:01:12         1
#           00:01:13         1
#           00:01:37         1
#           00:01:43         1
#           00:01:44         1
#           00:01:50         1
#           00:01:59         1
#           00:02:03         1
#           00:02:05         1
#           00:02:10         1
#           00:02:12         1
#           00:02:13         1
#           00:02:14         1
#           00:02:17         1
#           00:02:23         1
#           00:02:29         1
#           00:03:04         1
#           00:03:10         1
#           00:03:43         1
#           00:04:48         1
#           00:04:54         1
#           00:04:57         1
# vuiiscci  00:00:00         2
# yangkl    00:00:07         1
# Name: elapsed_time, Length: 433, dtype: int64

# %%
small_jobs_rolling = accre_user_elapsed[accre_user_elapsed['elapsed_time'] < timedelta(minutes = 5)].groupby('User').rolling('4h', on='Submit').JobID.count()
small_jobs_rolling
# Out:
# User      Submit
# autocms   2017-07-01 06:08:01      1.0
#           2017-07-01 11:04:01      1.0
#           2017-07-01 06:58:01      2.0
#           2017-07-01 12:21:01      3.0
#           2017-07-01 14:40:02      4.0
#           2017-07-01 12:40:01      5.0
#           2017-07-01 10:25:01      6.0
#           2017-07-01 05:10:01      7.0
#           2017-07-01 18:08:01      5.0
#           2017-07-01 05:01:01      6.0
#           2017-07-01 11:01:01      7.0
#           2017-07-01 14:21:01      8.0
#           2017-07-01 20:28:01      5.0
#           2017-07-01 18:00:01      6.0
#           2017-07-01 17:18:01      7.0
#           2017-07-01 14:20:01      8.0
#           2017-07-01 08:08:01      9.0
#           2017-07-01 09:47:01     10.0
#           2017-07-01 14:16:01     11.0
#           2017-07-01 08:38:01     12.0
#           2017-07-01 12:37:01     13.0
#           2017-07-01 08:05:02     14.0
#           2017-07-01 14:53:01     15.0
#           2017-07-01 07:47:02     16.0
#           2017-07-01 05:18:01     17.0
#           2017-07-01 16:22:01     18.0
#           2017-07-01 06:17:02     19.0
#           2017-07-01 20:19:02     20.0
#           2017-07-01 17:45:01     21.0
#           2017-07-01 08:06:02     22.0
#                                  ...
# uscms010  2017-07-01 13:45:04    686.0
#           2017-07-01 10:14:57    687.0
#           2017-07-01 19:45:15    688.0
#           2017-07-01 10:15:22    689.0
#           2017-07-01 11:15:04    690.0
#           2017-07-01 15:45:13    691.0
#           2017-07-01 11:14:58    692.0
#           2017-07-01 20:15:18    693.0
#           2017-07-01 20:14:51    694.0
#           2017-07-01 16:00:14    695.0
#           2017-07-01 16:44:39    696.0
#           2017-07-01 20:00:17    697.0
#           2017-07-01 12:00:08    698.0
#           2017-07-01 10:00:12    699.0
#           2017-07-01 11:59:50    700.0
#           2017-07-01 08:59:59    701.0
#           2017-07-01 17:30:10    702.0
#           2017-07-01 13:30:08    703.0
#           2017-07-01 18:00:10    704.0
#           2017-07-01 17:00:10    705.0
#           2017-07-01 15:14:46    706.0
#           2017-07-01 13:59:54    707.0
#           2017-07-01 19:29:59    708.0
#           2017-07-01 06:45:03    709.0
#           2017-07-01 14:00:15    710.0
#           2017-07-01 08:30:07    711.0
#           2017-07-01 15:15:09    712.0
# vuiiscci  2017-07-01 05:01:26      1.0
#           2017-07-01 05:01:26      2.0
# yangkl    2017-07-01 15:51:13      1.0
# Name: JobID, Length: 3142, dtype: float64

# %%
boxplot = accre_user_elapsed.boxplot(column='elapsed_time',by='User')

# %%
sns.jointplot(x='User', y='elapsed_time', data=data_returns

# %%
boxplot = accre_user_elapsed.boxplot ser.resample('D').sum().plot()
